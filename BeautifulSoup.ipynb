# %% [markdown]
# <a href="https://colab.research.google.com/github/wjdsheep15/AIStudy/blob/main/BeautifulSoup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * BeautifulSoup 라이브러리를 사용하여 HTML, XML에서 데이터 추츨

# %%
pip list

# %%
import requests
res = requests.get('https://www.daangn.com/hot_articles')
print(res.text)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#   <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
#   <meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no">
#
#
#
# <title>당근 중고거래 | 당신 근처의 당근</title>
# <meta name="description" content="당근에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근에서 거래되고 있는 다양한 매물을 구경해보세요." />
# <link rel="author" href="당근" />
# <meta property="og:url" content="https://www.daangn.com/hot_articles" />
# <meta property="og:title" content="당근 중고거래 | 당신 근처의 당근" />
# <meta property="og:description" content="당근에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근에서 거래되고 있는 다양한 매물을 구경해보세요." />
# <meta property="og:site_name" content="당근" />
# <meta property="og:image" content="https://www.daangn.com/images/meta/home/rebranded_daangn.png" />
# <meta property="og:type" content="article" />
# <meta property="og:locale" content="ko_KR" />
# <meta property="fb:app_id" content="1463621440622064" />
# ...

# %%
from bs4 import BeautifulSoup
webpage = requests.get("https://www.daangn.com/hot_articles")
soup =  BeautifulSoup(webpage.content, "html.parser")

print(soup)

# %%
print(soup.head.title)
# Out:
# <title>당근 중고거래 | 당신 근처의 당근</title>

# %%
print(soup.P)
# Out:
# None

# %%
print(soup.head.find('meta',{'name':'description'}).get('content'))
# Out:
# 당근에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근에서 거래되고 있는 다양한 매물을 구경해보세요.

# %%
for link in soup.find_all('a'):
  print(link.text.strip(), link.get('href'))
# Out:
#  https://www.daangn.com
# 중고거래 https://www.daangn.com/fleamarket/
# 동네가게 /kr/nearby-stores/
# 알바 /kr/jobs/
# 부동산 직거래 /kr/realty/
# 중고차 직거래 /kr/car/
# 밖에 한번 만 썼는데 집에 저장공간으로만 썼어요
#
#         2,000원
#
#
#         서울 성동구 용답동
#
#
#
#             관심 48
#
#         ∙
#
#             채팅 35 /articles/654158077
# 여성 꼼데가르송 가디건 정품
#
#         100,000원
#
#
#         서울 서초구 양재동
#
#
#
#             관심 46
#
#         ∙
#
#             채팅 26 /articles/650844685
# 참기름,들기름
#
#         10,000원
#
#
#         제주 제주시 노형동
#
#
#
#             관심 10
#
#         ∙
#
#             채팅 2 /articles/653551687
# 스타우브 꼬꼬떼 원형 18cm 화이트 트러플
#
#         30,000원
#
#
#         서울 강서구 화곡동
#
#
#
#             관심 19
#
#         ∙
#
#             채팅 14 /articles/650909177
# 베트남동
#
#         95,000원
#
#
#         충남 아산시 배방읍
#
#
#
#             관심 10
#
#         ∙
#
#             채팅 17 /articles/654194297
# 재고 옷 떨이
#
#         1,000원
#
#
#         서울 성북구 장위제2동
#
#
#
#             관심 36
#
#         ∙
#
# ...

# %%
print(soup.find_all("h2"))
# Out:
# [<h2 class="card-title">밖에 한번 만 썼는데 집에 저장공간으로만 썼어요</h2>, <h2 class="card-title">여성 꼼데가르송 가디건 정품</h2>, <h2 class="card-title">참기름,들기름</h2>, <h2 class="card-title">스타우브 꼬꼬떼 원형 18cm 화이트 트러플</h2>, <h2 class="card-title">베트남동</h2>, <h2 class="card-title">재고 옷 떨이</h2>, <h2 class="card-title">김동률콘서트 정가양도</h2>, <h2 class="card-title">온수매트</h2>, <h2 class="card-title">스팸햄선물세트 12호</h2>, <h2 class="card-title">이동식 티비 급처합니다</h2>, <h2 class="card-title">18K 진짜 금</h2>, <h2 class="card-title">경운기</h2>, <h2 class="card-title">접이식 카트</h2>, <h2 class="card-title">이케아 선반 팔아용!</h2>, <h2 class="card-title">샤인 머스켓</h2>, <h2 class="card-title">여러가지가구정리합니다(컴퓨터의자,매트리스,책상,건조대,옷걸이,무선청소기,접이식의자)</h2>, <h2 class="card-title">남여공용 고야드 볼테르 토트백</h2>, <h2 class="card-title">LG 42인치 TV</h2>, <h2 class="card-title">갤럭시 기어S3 프론티어 스마트워치</h2>, <h2 class="card-title">전부일괄입니다 새제품입니다</h2>, <h2 class="card-title">호두(새것)&amp;아몬드와 캐슈넛(맛만봄) 묶음모두</h2>, <h2 class="card-title">디올 오블리크 카드지갑 판매합니다</h2>, <h2 class="card-title">들기름</h2
# ...

# %%
soup.find_all(attrs={'class' : 'card-title'})
# Out:
# [<h2 class="card-title">밖에 한번 만 썼는데 집에 저장공간으로만 썼어요</h2>,
#  <h2 class="card-title">여성 꼼데가르송 가디건 정품</h2>,
#  <h2 class="card-title">참기름,들기름</h2>,
#  <h2 class="card-title">스타우브 꼬꼬떼 원형 18cm 화이트 트러플</h2>,
#  <h2 class="card-title">베트남동</h2>,
#  <h2 class="card-title">재고 옷 떨이</h2>,
#  <h2 class="card-title">김동률콘서트 정가양도</h2>,
#  <h2 class="card-title">온수매트</h2>,
#  <h2 class="card-title">스팸햄선물세트 12호</h2>,
#  <h2 class="card-title">이동식 티비 급처합니다</h2>,
#  <h2 class="card-title">18K 진짜 금</h2>,
#  <h2 class="card-title">경운기</h2>,
#  <h2 class="card-title">접이식 카트</h2>,
#  <h2 class="card-title">이케아 선반 팔아용!</h2>,
#  <h2 class="card-title">샤인 머스켓</h2>,
#  <h2 class="card-title">여러가지가구정리합니다(컴퓨터의자,매트리스,책상,건조대,옷걸이,무선청소기,접이식의자)</h2>,
#  <h2 class="card-title">남여공용 고야드 볼테르 토트백</h2>,
#  <h2 class="card-title">LG 42인치 TV</h2>,
#  <h2 class="card-title">갤럭시 기어S3 프론티어 스마트워치</h2>,
#  <h2 class="card-title">전부일괄입니다 새제품입니다</h2>,
#  <h2 class="card-title">호두(새것)&amp;아몬드와 캐슈넛(맛만봄) 묶음모두</h2>,
# ...

# %%
for x in range(0,10):
  print(soup.select(".card-title")[x].get_text())
# Out:
# 밖에 한번 만 썼는데 집에 저장공간으로만 썼어요
# 여성 꼼데가르송 가디건 정품
# 참기름,들기름
# 스타우브 꼬꼬떼 원형 18cm 화이트 트러플
# 베트남동
# 재고 옷 떨이
# 김동률콘서트 정가양도
# 온수매트
# 스팸햄선물세트 12호
# 이동식 티비 급처합니다
